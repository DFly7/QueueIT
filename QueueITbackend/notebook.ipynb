# %% [markdown]
# ### Show Image From Request

# %%
import sys
sys.path.append('/Users/darraghflynn/Desktop/codeAdventures/QueueIT/QueueITbackend')

import main as m

data = m.get_spotify_data()
# Out:
# {
#   "tracks": {
#     "limit": 1,
#     "next": null,
#     "offset": 0,
#     "previous": null,
#     "total": 1,
#     "items": [
#       {
#         "album": {
#           "album_type": "album",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb"
#               },
#               "id": "4Z8W4fKeB5YxbusRsdQVPb",
#               "name": "Radiohead",
#               "type": "artist",
#               "uri": "spotify:artist:4Z8W4fKeB5YxbusRsdQVPb"
#             }
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/6GjwtEZcfenmOf6l18N7T7"
#           },
#           "id": "6GjwtEZcfenmOf6l18N7T7",
#           "images": [
#             {
#               "height": 640,
#               "width": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b2736c7112082b63beefffe40151"
#             },
#             {
# ...

# %%
print(data["tracks"])
# Out:
# {'limit': 1, 'next': None, 'offset': 0, 'previous': None, 'total': 1, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'}, 'id': '4Z8W4fKeB5YxbusRsdQVPb', 'name': 'Radiohead', 'type': 'artist', 'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6GjwtEZcfenmOf6l18N7T7'}, 'id': '6GjwtEZcfenmOf6l18N7T7', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2736c7112082b63beefffe40151'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e026c7112082b63beefffe40151'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d000048516c7112082b63beefffe40151'}], 'is_playable': True, 'name': 'Kid A', 'release_date': '2000-10-02', 'release_date_precision': 'day', 'total_tracks': 11, 'type': 'album', 'uri': 'spotify:album:6GjwtEZcfenmOf6l18N7T7'}, 'artists': [{'external_urls':
# ...

# %%
from IPython.display import Image, display

track = data["tracks"]["items"][0]
print(track)
image_url = track["album"]["images"][0]["url"]
print(image_url)
print("Track:", track["name"], "by", track["artists"][0]["name"])

display(Image(url=image_url))
# Out:
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'}, 'id': '4Z8W4fKeB5YxbusRsdQVPb', 'name': 'Radiohead', 'type': 'artist', 'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6GjwtEZcfenmOf6l18N7T7'}, 'id': '6GjwtEZcfenmOf6l18N7T7', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2736c7112082b63beefffe40151'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e026c7112082b63beefffe40151'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d000048516c7112082b63beefffe40151'}], 'is_playable': True, 'name': 'Kid A', 'release_date': '2000-10-02', 'release_date_precision': 'day', 'total_tracks': 11, 'type': 'album', 'uri': 'spotify:album:6GjwtEZcfenmOf6l18N7T7'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'}, 'id': '4
# ...

# %%
image_url2 = track["album"]["images"][1]["url"]
print(image_url2)

display(Image(url=image_url2))
# Out:
# https://i.scdn.co/image/ab67616d00001e026c7112082b63beefffe40151
# <img src="https://i.scdn.co/image/ab67616d00001e026c7112082b63beefffe40151"/>

# %%
image_url3 = track["album"]["images"][2]["url"]
print(image_url3)

display(Image(url=image_url3))
# Out:
# https://i.scdn.co/image/ab67616d000048516c7112082b63beefffe40151
# <img src="https://i.scdn.co/image/ab67616d000048516c7112082b63beefffe40151"/>
